# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrizionicolay/Big_Data_Colab/blob/main/Graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos la libreria 'matplotlib'
import matplotlib.pyplot as plt

# %%
#configuramos el grafico_
# indicamos que la distribucion de esos 2 graficos sera de 1 fila y 2 columnas
# Tamaño del grafico sera de 8*6 pulgadas
fig, graficos = plt.subplots(1,2,figsize=(8,6))

graficos[0].scatter(
    x=[1,2,3],
    y=[3,2,1]
)

graficos[1].scatter(
    x=[2,4,6,8,10],
    y=[4,16,35,64,100]
)

plt.show()

# %%
import numpy as np

# %% [markdown]
# #GRAFICO 3

# %%
fig, graficos = plt.subplots(1,2,figsize=(8,6))

#Graficamos "puntos" en las coordenadas X e Y en el primer grafico (0)
graficos[0].scatter(
    x=[1,2,3],
    y=[3,2,1]
)
#Graficamos una función cuadrática con valores desde -10 hasta 10 de 0.25, para
#ello nos apoyamos en numpy y su función 'arange'.
eje_x = np.arange(-10,10,0.25)
eje_y = []#aquí guardaremos los cuadrados

for numero in eje_x:
    cuadrado = numero*numero #calculamos el cuadrado de cada elemento
    eje_y.append(cuadrado) #lo agregamos a 'eje_y'

#graficos[1].scatter(
#    x = eje_x,
#    y = eje_y
#)

#graficamos con 'plot' en vez de 'scatter' para dibujar lineas en vez de puntos.
graficos[1].plot(
    eje_x,
    eje_y
)

plt.show() #visualizamos ambos gráficos.

# %% [markdown]
# #GRAFICO 4

# %%
#importamos la libreria matplotlib
import matplotlib.pyplot as plt
import numpy as np

#configuramos el grafico_
# indicamos que la distribucion de esos 2 graficos sera de 1 fila y 2 columnas
# Tamaño del grafico sera de 8*6 pulgadas

fig, graficos = plt.subplots(figsize=(8,6))

eje_x = np.arange(-10,10,0.2) #valores cualquiera que para el ejemplo se espresa en Radianes
eje_y = [] #aqui guardamos el valor de la función Seno para cada elemento de "eje_x"

for number in eje_x: #iteramos...
    vseno = np.sin(number) #calculamos el seno de cada numero de "eje_x"
    eje_y.append(vseno) #lo almacenamos
    print(vseno)

#graficamos
graficos.plot(
    eje_x,
    eje_y
)

plt.show()#visualizamos ambos gráficos.
# Out:
# 0.5440211108893698
# 0.3664791292519284
# 0.1743267812229814
# -0.02477542545335599
# -0.2228899141002442
# -0.4121184852417533
# -0.5849171928917588
# -0.7343970978741098
# -0.8545989080882778
# -0.9407305566797707
# -0.9893582466233808
# -0.9985433453746054
# -0.9679196720314885
# -0.8987080958116308
# -0.7936678638491591
# -0.6569865987187972
# -0.4941133511386182
# -0.3115413635133897
# -0.11654920485050599
# 0.08308940281748313
# 0.2794154981989122
# 0.464602179413744
# 0.6312666378723092
# 0.772764487555977
# 0.8834546557201453
# 0.9589242746631335
# 0.996164608835839
# 0.9936910036334666
# 0.9516020738895221
# 0.8715757724135982
# 0.7568024953079422
# 0.6118578909427365
# 0.4425204432948728
# 0.255541102026854
# 0.058374143427604025
# -0.1411200080598426
# -0.3349881501558808
# -0.5155013718214417
# -0.675463180551131
# -0.8084964038195739
# -0.9092974268256698
# -0.9738476308781886
# -0.9995736030415043
# -0.9854497299884654
# -0.9320390859672377
# -0.8414709848079138
# ...
